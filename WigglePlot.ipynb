# %% [markdown]
# # Plot Prior Potentials

# %%
import wiggle
from wiggle import Wiggle, load_wiggles
import matplotlib.pyplot as plt
from imp import reload
reload(wiggle)
# Out:
# <module 'wiggle' from '/home/jovyan/work/wiggle.py'>

# %%
wiggleSW = Wiggle()
wiggleGAP = Wiggle()
wiggleDiff = Wiggle()
wiggleSW.load('Wiggles/Empirical/IP SW.p')
wiggleGAP.load('Wiggles/Empirical/Empirical.p')
wiggleTersoff.load('Wiggles/Empirical/Diff.p')
# Out:
# Attempting to load potentials from "Wiggles/Empirical/IP SW.p".
# Successfully loaded potentials from "Wiggles/Empirical/IP SW.p".
# Attempting to load potentials from "Wiggles/Empirical/Empirical.p".
# Successfully loaded potentials from "Wiggles/Empirical/Empirical.p".
# Attempting to load potentials from "Wiggles/Empirical/Diff.p".
# Successfully loaded potentials from "Wiggles/Empirical/Diff.p".
# (array([[-1.        , -0.89473684, -0.78947368, -0.68421053, -0.57894737,
#          -0.47368421, -0.36842105, -0.26315789, -0.15789474, -0.05263158,
#           0.05263158,  0.15789474,  0.26315789,  0.36842105,  0.47368421,
#           0.57894737,  0.68421053,  0.78947368,  0.89473684,  1.        ],
#         [-1.        , -0.89473684, -0.78947368, -0.68421053, -0.57894737,
#          -0.47368421, -0.36842105, -0.26315789, -0.15789474, -0.05263158,
#           0.05263158,  0.15789474,  0.26315789,  0.36842105,  0.47368421,
# ...

# %%
fig, ax, h = wiggleDiff.plot()
ax.set_title('Difference between Stillinger-Weber and GAP1k')
fig.savefig('NewPlots/Wiggle/Diff.pdf')
# Out:
# Plotting potential distribution...

# %%
wiggles = genera

# %%
wiggles = generate_wiggles('Wiggles/prior/prior%d.p')
# Out:
# Attempting to load potentials from "Wiggles/prior/prior0.p".
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# <ipython-input-3-07e19b9d4383> in <module>
# ----> 1 wiggles = load_wiggles('Wiggles/prior/prior%d.p')
#
# ~/work/wiggle.py in load_wiggles(filestring, start, stop)
#      21         for i in range(start, stop):
#      22             filepath = (filestring.replace('%d', str(i)))
# ---> 23             wiggles.append(Wiggle(filepath = filepath))
#      24
#      25     except FileNotFoundError:
#
# ~/work/wiggle.py in __init__(self, atom, structure, lattice_constant, filepath)
#      57         if self.filepath != None:
#      58             self.filepath = filepath
# ---> 59             self.load(filepath)
#      60
#      61         else:
#
# ~/work/wiggle.py in load(self, filepath)
#     145         try:
# ...

# %%
fig, axes = plt.subplots(1,2)
wiggleSW.plot_ax(axes[0])
wiggleGAP.plot_ax(axes[1])
axes[1].set_ylabel('')
# Out:
# Plotting potential distribution on ax...
# Plotting potential distribution on ax...
# Text(0, 0.5, '')

# %%
wiggleDiff = Wiggle()
wiggleDiff.energies = wiggleSW.energies - wiggleGAP.energies
wiggleDiff.x = wiggleSW.x
wiggleDiff.y = wiggleSW.y
wiggleDiff.calc_name = 'Diff'
wiggleDiff.save('Wiggles/Empirical/Diff.p')

fig, ax, h = wiggleDiff.plot()
ax.set_title('Difference in SW and GAP1k Potential')
fig.savefig('plots/Wiggles/Diff.pdf')

# %%
wiggles = load_wiggles('Wiggles/prior/prior%d.p')
wiggles005 = load_wiggles('Wiggles/weighted0.05/weight0.05prior%d.p')
wiggles01  = load_wiggles('Wiggles/weighted0.1/weight0.10prior%d.p')
wiggles1   = load_wiggles('Wiggles/weighted1/weight1.0prior%d.p')
wiggles5   = load_wiggles('Wiggles/weighted5/weight5.0prior%d.p')
wiggles10  = load_wiggles('Wiggles/weighted10/weight10.0prior%d.p')
# Out:
# Attempting to load potentials from "Wiggles/weighted0.01/weight0.01prior0.p".
# Successfully loaded potentials from "Wiggles/weighted0.01/weight0.01prior0.p".
# Attempting to load potentials from "Wiggles/weighted0.01/weight0.01prior1.p".
# Successfully loaded potentials from "Wiggles/weighted0.01/weight0.01prior1.p".
# Attempting to load potentials from "Wiggles/weighted0.01/weight0.01prior2.p".
# Successfully loaded potentials from "Wiggles/weighted0.01/weight0.01prior2.p".
# Attempting to load potentials from "Wiggles/weighted0.01/weight0.01prior3.p".
# Successfully loaded potentials from "Wiggles/weighted0.01/weight0.01prior3.p".
# Attempting to load potentials from "Wiggles/weighted0.01/weight0.01prior4.p".
# Successfully loaded potentials from "Wiggles/weighted0.01/weight0.01prior4.p".
# Attempting to load potentials from "Wiggles/weighted0.01/weight0.01prior5.p".
# Successfully loaded potentials from "Wiggles/weighted0.01/weight0.01prior5.p".
# ...

# %%
wiggles = load_wiggles('Wiggles/prior/prior%d.p')
# Out:
# Attempting to load potentials from "Wiggles/prior/prior0.p".
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# <ipython-input-19-07e19b9d4383> in <module>
# ----> 1 wiggles = load_wiggles('Wiggles/prior/prior%d.p')
#
# ~/work/wiggle.py in load_wiggles(filestring, start, stop)
#      21         for i in range(start, stop):
#      22             filepath = (filestring.replace('%d', str(i)))
# ---> 23             wiggles.append(Wiggle(filepath = filepath))
#      24
#      25     except FileNotFoundError:
#
# ~/work/wiggle.py in __init__(self, atom, structure, lattice_constant, filepath)
#      57         if self.filepath != None:
#      58             self.filepath = filepath
# ---> 59             self.load(filepath)
#      60
#      61         else:
#
# ~/work/wiggle.py in load(self, filepath)
#     145         try:
# ...

# %%
for wiggle in wiggles001[:5]:
    wiggle.plot()

for wiggle in wiggles005[:5]:
    wiggle.plot()

for wiggle in wiggles01[:5]:
    wiggle.plot()

for wiggle in wiggles1[:5]:
    wiggle.plot()

for wiggle in wiggles5[:5]:
    wiggle.plot()

for wiggle in wiggles10[:5]:
    wiggle.plot()
# Out:
# Plotting potential distribution...
# Plotting potential distribution...
# Plotting potential distribution...
# Plotting potential distribution...
# Plotting potential distribution...
# Plotting potential distribution...
# Plotting potential distribution...
# Plotting potential distribution...
# Plotting potential distribution...
# Plotting potential distribution...
# Plotting potential distribution...
# Plotting potential distribution...
# Plotting potential distribution...
# Plotting potential distribution...
# Plotting potential distribution...
# Plotting potential distribution...
# Plotting potential distribution...
# Plotting potential distribution...
# Plotting potential distribution...
# Plotting potential distribution...
# ...

# %%
#50pct Prior

wiggles = load_wiggles('Wiggles/weighted0.05/weight0.05prior%d.p')
# Out:
# Attempting to load potentials from "Wiggles/weighted0.05/weight0.05prior0.p".
# Successfully loaded potentials from "Wiggles/weighted0.05/weight0.05prior0.p".
# Attempting to load potentials from "Wiggles/weighted0.05/weight0.05prior1.p".
# Successfully loaded potentials from "Wiggles/weighted0.05/weight0.05prior1.p".
# Attempting to load potentials from "Wiggles/weighted0.05/weight0.05prior2.p".
# Successfully loaded potentials from "Wiggles/weighted0.05/weight0.05prior2.p".
# Attempting to load potentials from "Wiggles/weighted0.05/weight0.05prior3.p".
# Successfully loaded potentials from "Wiggles/weighted0.05/weight0.05prior3.p".
# Attempting to load potentials from "Wiggles/weighted0.05/weight0.05prior4.p".
# Successfully loaded potentials from "Wiggles/weighted0.05/weight0.05prior4.p".
# Attempting to load potentials from "Wiggles/weighted0.05/weight0.05prior5.p".
# Successfully loaded potentials from "Wiggles/weighted0.05/weight0.05prior5.p".
# ...

# %%
for wiggle in wiggles:
    wiggle.plot()
# Out:
# Plotting potential distribution
# Plotting potential distribution
# Plotting potential distribution
# Plotting potential distribution
# Plotting potential distribution
# Plotting potential distribution
# Plotting potential distribution
# Plotting potential distribution
# Plotting potential distribution
# Plotting potential distribution
# Plotting potential distribution
# Plotting potential distribution
# Plotting potential distribution
# Plotting potential distribution
# Plotting potential distribution
# Plotting potential distribution
# Plotting potential distribution
# Plotting potential distribution
# Plotting potential distribution
# Plotting potential distribution
